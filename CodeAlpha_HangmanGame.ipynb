# %% [markdown]
# <a href="https://colab.research.google.com/github/HammadSadique786/CodeAlpha_PythonProjects/blob/main/CodeAlpha_HangmanGame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

words = ["apple", "tiger", "chair", "robot", "green"]

word = random.choice(words)

guessed_letters = []
wrong_guesses = 0
max_wrong = 6

display = ["_"] * len(word)

print("🎮 Welcome to Hangman Game!")
print("Guess the word letter by letter.\n")

while wrong_guesses < max_wrong and "_" in display:
    print("Word:", " ".join(display))
    print(f"Wrong guesses left: {max_wrong - wrong_guesses}")
    print("Guessed letters:", ", ".join(guessed_letters))

    guess = input("Enter a letter: ").lower().strip()

    if not guess.isalpha() or len(guess) != 1:
        print("⚠️ Please enter ONLY one alphabet letter!\n")
        continue

    if guess in guessed_letters:
        print("⚠️ You already guessed that letter!\n")
        continue

    guessed_letters.append(guess)

    if guess in word:
        print("✅ Correct guess!\n")
        for i in range(len(word)):
            if word[i] == guess:
                display[i] = guess
    else:
        print("❌ Wrong guess!\n")
        wrong_guesses += 1

if "_" not in display:
    print("\n🎉 Congratulations! You guessed the word:", word)
else:
    print("\n💀 Game Over! The word was:", word)
# Out:
# 🎮 Welcome to Hangman Game!
# Guess the word letter by letter.
#
# Word: _ _ _ _ _
# Wrong guesses left: 6
# Guessed letters:
# Enter a letter: p
# ✅ Correct guess!
#
# Word: _ p p _ _
# Wrong guesses left: 6
# Guessed letters: p
# Enter a letter: y
# ❌ Wrong guess!
#
# Word: _ p p _ _
# Wrong guesses left: 5
# Guessed letters: p, y
# Enter a letter: t
# ❌ Wrong guess!
#
# Word: _ p p _ _
# Wrong guesses left: 4
# Guessed letters: p, y, t
# Enter a letter: a
# ✅ Correct guess!
#
# Word: a p p _ _
# Wrong guesses left: 4
# Guessed letters: p, y, t, a
# Enter a letter: l
# ✅ Correct guess!
#
# Word: a p p l _
# Wrong guesses left: 4
# Guessed letters: p, y, t, a, l
# Enter a letter: g
# ❌ Wrong guess!
#
# Word: a p p l _
# Wrong guesses left: 3
# Guessed letters: p, y, t, a, l, g
# Enter a letter: s
# ❌ Wrong guess!
#
# Word: a p p l _
# Wrong guesses left: 2
# Guessed letters: p, y, t, a, l, g, s
# Enter a letter: e
# ✅ Correct guess!
#
#
# ...
