# %% [markdown]
# <a href="https://colab.research.google.com/github/HammadSadique786/CodeAlpha_PythonProjects/blob/main/CodeAlpha_BasicChatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def chatbot_response(user_input):
    user_input = user_input.lower()

    if user_input == "hello" or user_input == "hi":
        return "Hi! How can I help you?"
    elif user_input == "how are you":
        return "I'm fine, thanks! How are you?"
    elif user_input == "what is your name":
        return "My name is CodeAlpha Chatbot."
    elif user_input == "help":
        return "You can ask me: hello, how are you, what is your name, bye."
    elif user_input == "bye":
        return "Goodbye! Have a nice day."
    else:
        return "Sorry, I don't understand that. Type 'help' for options."

print("Welcome to Basic Chatbot!")
print("Type 'bye' to exit.")

while True:
    user_message = input("\nYou: ")
    response = chatbot_response(user_message)

    print("Bot:", response)

    if user_message.lower() == "bye":
        break
